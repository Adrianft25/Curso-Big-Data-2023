# %% [markdown]
# <a href="https://colab.research.google.com/github/Adrianft25/Curso-Big-Data-2023/blob/main/ETL_Python_y_SQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ejercicio ETL

# %% [markdown]
# ### Resumen
#
# A partir de una fuente de datos opensource en [Kaggle](https://www.kaggle.com/datasets/michau96/restaurant-business-rankings-2020) hemos creado montado ETL. Extraído, procesado y cargado los datos en una BBDD (base de datos).
#
#
# ---
#
#
# ## Obtención de datos
#
# INPUT: 3 archivos CSV con las clasificaciones de los mejores restaurantes de 2020.
#
#
#
# *   Future 50:
# Clasificaciones de los futuros 50 mejores restaurantes.
# *   Independence 100:
# Clasificaciones de los 100 mejores restaurantes independientes de 2020.
# *   Top 250:
# Clasificaciones de los 250 mejores restaurantes de 2020.
#
# Todos los datos se extrajeron de Restaurant Business Online y están basados en informes financieros de la empresa, encuestas, documentos de las franquicias y algoritmos de valoración.

# %%
#Dependencias
# !pip install sqlalchemy==1.4.16 --quiet
import pandas as pd
import numpy as np
#Instalamos e importamos MySQL para Python
# !pip install PyMySQL --quiet
import pymysql as pymsql
# !pip install mysql-connector --quiet
import mysql.connector
from sqlalchemy import create_engine
# !pip install sqlalchemy-utils --quiet
from sqlalchemy_utils import database_exists, create_database

# %% [markdown]
# ## Extraer CSVs en DataFrame

# %%
#1. Leer el archivo top250 y ver el dataframe
top250_file = "https://drive.google.com/uc?id=10fsqUk01wJeLUcArcBN2JUg86C3lKLQm&export=download"
top250 = pd.read_csv(top250_file)
top250.head()
# Out:
#    Rank   Restaurant                                            Content  \
# 0     1   McDonald's                                                NaN
# 1     2    Starbucks                                                NaN
# 2     3  Chick-fil-A  While Popeyes got a lot of the chicken buzz in...
# 3     4    Taco Bell                                                NaN
# 4     5  Burger King                                                NaN
#
#    Sales YOY_Sales  Units YOY_Units Headquarters             Segment_Category
# 0  40412      4.9%  13846     -0.5%          NaN       Quick Service & Burger
# 1  21380      8.6%  15049      3.0%          NaN  Quick Service & Coffee Cafe
# 2  11320     13.0%   2470      5.0%          NaN      Quick Service & Chicken
# 3  11293      9.0%   6766      2.7%          NaN      Quick Service & Mexican
# 4  10204      2.7%   7346      0.2%          NaN       Quick Service & Burger

# %%
#2. Leer el archivo Future50 y ver el dataframe
future50_file = "https://drive.google.com/uc?id=15zBrVc3kx7QxYkNaFaNVfh-a0uj-TKbo&export=download"
#Carga el archivo future50_file en el dataframe future50
future50 = pd.read_csv(future50_file)
future50.head()
# Out:
#    Rank   Restaurant                  Location  Sales YOY_Sales  Units  \
# 0     1   Evergreens            Seattle, Wash.     24    130.5%     26
# 1     2  Clean Juice           Charlotte, N.C.     44    121.9%    105
# 2     3     Slapfish  Huntington Beach, Calif.     21     81.0%     21
# 3     4   Clean Eatz          Wilmington, N.C.     25     79.7%     46
# 4     5    Pokeworks            Irvine, Calif.     49     77.1%     50
#
#   YOY_Units  Unit_Volume Franchising
# 0    116.7%         1150          No
# 1     94.4%          560         Yes
# 2     90.9%         1370         Yes
# 3     58.6%          685         Yes
# 4     56.3%         1210         Yes

# %%
#3. Leer el archivo Independence100 y ver el dataframe
ind100_file = "https://drive.google.com/uc?id=1cg8-zWjWkD1iRuRMDs5DZmSqnhHhHNcA&export=download"
#Carga el archivo ind100_file en el dataframe ind100
ind100 = pd.read_csv(ind100_file)
ind100.head()
# Out:
#    Rank                           Restaurant       Sales  Average Check  \
# 0     1             Carmine's (Times Square)  39080335.0             40
# 1     2                The Boathouse Orlando  35218364.0             43
# 2     3                     Old Ebbitt Grill  29104017.0             33
# 3     4  LAVO Italian Restaurant & Nightclub  26916180.0             90
# 4     5             Bryant Park Grill & Cafe  26900000.0             62
#
#          City State  Meals Served
# 0    New York  N.Y.      469803.0
# 1    Orlando   Fla.      820819.0
# 2  Washington  D.C.      892830.0
# 3    New York  N.Y.      198500.0
# 4    New York  N.Y.      403000.0

# %% [markdown]
# ## Modificar DataFrames

# %%
#Renombrar la columna Sales a Sales_in_millions del dataframe future50
future50 = future50.rename(columns={'Sales': 'Sales_in_millions'})
future50.head()
# Out:
#    Rank   Restaurant                  Location  Sales_in_millions YOY_Sales  \
# 0     1   Evergreens            Seattle, Wash.                 24    130.5%
# 1     2  Clean Juice           Charlotte, N.C.                 44    121.9%
# 2     3     Slapfish  Huntington Beach, Calif.                 21     81.0%
# 3     4   Clean Eatz          Wilmington, N.C.                 25     79.7%
# 4     5    Pokeworks            Irvine, Calif.                 49     77.1%
#
#    Units YOY_Units  Unit_Volume Franchising
# 0     26    116.7%         1150          No
# 1    105     94.4%          560         Yes
# 2     21     90.9%         1370         Yes
# 3     46     58.6%          685         Yes
# 4     50     56.3%         1210         Yes

# %%
#Renombrar la columna Sales a Sales_in_millions de top250
top250 = top250.rename(columns={'Sales': 'Sales_in_millions'})
top250.head()
# Out:
#    Rank   Restaurant                                            Content  \
# 0     1   McDonald's                                                NaN
# 1     2    Starbucks                                                NaN
# 2     3  Chick-fil-A  While Popeyes got a lot of the chicken buzz in...
# 3     4    Taco Bell                                                NaN
# 4     5  Burger King                                                NaN
#
#    Sales_in_millions YOY_Sales  Units YOY_Units Headquarters  \
# 0              40412      4.9%  13846     -0.5%          NaN
# 1              21380      8.6%  15049      3.0%          NaN
# 2              11320     13.0%   2470      5.0%          NaN
# 3              11293      9.0%   6766      2.7%          NaN
# 4              10204      2.7%   7346      0.2%          NaN
#
#               Segment_Category
# 0       Quick Service & Burger
# 1  Quick Service & Coffee Cafe
# 2      Quick Service & Chicken
# 3      Quick Service & Mexican
# 4       Quick Service & Burger

# %%
#Eliminar las columnas Content y Headquarters de top250 --> ["Content", "Headquarters"]
top250 = top250.drop(['Content', 'Headquarters'], axis=1)
top250.head()
# Out:
#    Rank   Restaurant  Sales_in_millions YOY_Sales  Units YOY_Units  \
# 0     1   McDonald's              40412      4.9%  13846     -0.5%
# 1     2    Starbucks              21380      8.6%  15049      3.0%
# 2     3  Chick-fil-A              11320     13.0%   2470      5.0%
# 3     4    Taco Bell              11293      9.0%   6766      2.7%
# 4     5  Burger King              10204      2.7%   7346      0.2%
#
#               Segment_Category
# 0       Quick Service & Burger
# 1  Quick Service & Coffee Cafe
# 2      Quick Service & Chicken
# 3      Quick Service & Mexican
# 4       Quick Service & Burger

# %%
#Hacer que las unidades de la columna sales coincidan en las tablas
#Pasos:
# Dividir la columna del dataframe Sales entre 1000000
sales_mils = ind100["Sales"] / 1000000
#Asignar a la columna del dataframe Sales la lista sales_mils
ind100["Sales"] = sales_mils
#Renombrar la columna Sales a Sales_in_millions
ind100 = ind100.rename(columns={'Sales': 'Sales_in_millions'})
ind100.head()
# Out:
#    Rank                           Restaurant  Sales_in_millions  \
# 0     1             Carmine's (Times Square)          39.080335
# 1     2                The Boathouse Orlando          35.218364
# 2     3                     Old Ebbitt Grill          29.104017
# 3     4  LAVO Italian Restaurant & Nightclub          26.916180
# 4     5             Bryant Park Grill & Cafe          26.900000
#
#    Average Check        City State  Meals Served
# 0             40    New York  N.Y.      469803.0
# 1             43    Orlando   Fla.      820819.0
# 2             33  Washington  D.C.      892830.0
# 3             90    New York  N.Y.      198500.0
# 4             62    New York  N.Y.      403000.0

# %% [markdown]
# ### Agrupar Independent 100 por Restaurant

# %%
# Agrupar las filas por Restaurant y se suman
ind100_grouped = ind100.groupby(['Restaurant']).sum()
# Eliminar las columnas Rank y Average Check
ind100_grouped = ind100_grouped.drop(columns=['Rank', 'Average Check'])
# Agrupar por restaurant y average check, después añadir a ind100_grouped
avg_check = ind100.groupby(['Restaurant']).mean()
ind100_grouped['Average Check'] = avg_check['Average Check']
# Agrupar por restaurant y obtener el número de veces que aparece ese restaurante
counts = ind100.groupby(['Restaurant']).count()
ind100_grouped['Restaurant Count'] = counts['Rank']
# Ordenar por Sales de manera descendente
ind100_grouped = ind100_grouped.sort_values(by='Sales_in_millions', ascending=False)
# Restablecer el índice para mostrar el nuevo rango
ind100_grouped = ind100_grouped.reset_index()
# Mostrar cómo quedaría el DataFrame
ind100_grouped.head()
# Out:
# <ipython-input-44-ffbef7f93070>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ind100_grouped = ind100.groupby(['Restaurant']).sum()
# <ipython-input-44-ffbef7f93070>:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   avg_check = ind100.groupby(['Restaurant']).mean()
#                                 Restaurant  Sales_in_millions  Meals Served  \
# 0  Joe's Seafood, Prime Steak & Stone Crab          69.501000      816350.0
# 1                 Gibsons Bar & Steakhouse          63.724826      877430.0
# 2                 Carmine's (Times Square)          39.080335      469803.0
# 3                    The Boathouse Orlando          35.218364      820819.0
# 4                         Old Ebbitt Grill          29.104017      892830.0
#
#    Average Check  Restaurant Count
# 0           86.0                 3
# 1           80.0                 3
# 2           40.0                 1
# 3           43.0                 1
# 4           33.0                 1

# %% [markdown]
# ### Juntar Future50 e Ind100 por localización

# %%
# Paso 1. Hacer una copia de Future 50 df en la variable future50_df
future50_df = future50
future50_df.head()
# Out:
#    Rank   Restaurant                  Location  Sales_in_millions YOY_Sales  \
# 0     1   Evergreens            Seattle, Wash.                 24    130.5%
# 1     2  Clean Juice           Charlotte, N.C.                 44    121.9%
# 2     3     Slapfish  Huntington Beach, Calif.                 21     81.0%
# 3     4   Clean Eatz          Wilmington, N.C.                 25     79.7%
# 4     5    Pokeworks            Irvine, Calif.                 49     77.1%
#
#    Units YOY_Units  Unit_Volume Franchising
# 0     26    116.7%         1150          No
# 1    105     94.4%          560         Yes
# 2     21     90.9%         1370         Yes
# 3     46     58.6%          685         Yes
# 4     50     56.3%         1210         Yes

# %%
# Paso 2. Dividimos la columna Location de Future50 en dos nuevas columnas, City y State en un nuevo DataFrame
# Para ello usamos el método split y le pedimos que divida por comas
future50_split = future50_df["Location"].str.split(",", n = 1, expand = True)
future50_split.head()
# Out:
#                   0        1
# 0           Seattle    Wash.
# 1         Charlotte     N.C.
# 2  Huntington Beach   Calif.
# 3        Wilmington     N.C.
# 4            Irvine   Calif.

# %%
# Paso 3. Crear las columnas City y State dentro de future50_df 
# Pista: Se instancia el valor como en las listas (con el índice)
future50_df["City"]= future50_split[0]
future50_df["State"]= future50_split[1]
# Eliminar las columnas innecesarias --> ['Location', 'YOY_Sales', 'Units', 'YOY_Units', 'Unit_Volume', 'Franchising' ]
future50_df = future50_df.drop(['Location', 'YOY_Sales', 'Units', 'YOY_Units', 'Unit_Volume', 'Franchising'], axis=1)
future50_df.head()
# Out:
#    Rank   Restaurant  Sales_in_millions              City    State
# 0     1   Evergreens                 24           Seattle    Wash.
# 1     2  Clean Juice                 44         Charlotte     N.C.
# 2     3     Slapfish                 21  Huntington Beach   Calif.
# 3     4   Clean Eatz                 25        Wilmington     N.C.
# 4     5    Pokeworks                 49            Irvine   Calif.

# %%
# Paso 4. Crear una copia de Ind100 df en la variable ind100_df 
ind100_df = ind100
#Ahora elimina columnas innecesarias --> ['Average Check', 'Meals Served']
ind100_df = ind100_df.drop(['Average Check', 'Meals Served'], axis=1)
ind100_df.head()
# Out:
#    Rank                           Restaurant  Sales_in_millions        City  \
# 0     1             Carmine's (Times Square)          39.080335    New York
# 1     2                The Boathouse Orlando          35.218364    Orlando
# 2     3                     Old Ebbitt Grill          29.104017  Washington
# 3     4  LAVO Italian Restaurant & Nightclub          26.916180    New York
# 4     5             Bryant Park Grill & Cafe          26.900000    New York
#
#   State
# 0  N.Y.
# 1  Fla.
# 2  D.C.
# 3  N.Y.
# 4  N.Y.

# %%
future50_df
# Out:
#     Rank                        Restaurant  Sales_in_millions  \
# 0      1                        Evergreens                 24
# 1      2                       Clean Juice                 44
# 2      3                          Slapfish                 21
# 3      4                        Clean Eatz                 25
# 4      5                         Pokeworks                 49
# 5      6                       Playa Bowls                 39
# 6      7                  The Simple Greek                 24
# 7      8                         Melt Shop                 20
# 8      9                        Creamistry                 24
# 9     10              Joella's Hot Chicken                 29
# 10    11                     Eggs Up Grill                 30
# 11    12                          Dog Haus                 39
# 12    13                  Teriyaki Madness                 41
# 13    14                    Bluestone Lane                 48
# 14    15                 Original ChopShop                 21
# 15    16                 Rapid Fired Pizza                 24
# 16    17           Ike's Love & Sandwiches                 44
# 17    18                    Vitality Bowls                 37
# 18    19         Hawkers Asian Street Fare                 22
# 19    20          Maple Street Biscuit Co.                 39
# 20    21                   Bulla Gastrobar                 32
# 21    22                       Duck Donuts                 44
# 22    23                   The Little Beet                 23
# 23    24                   Joe & The Juice                 47
# 24    25                          By Chloe                 37
# 25    26              Sugarfire Smokehouse                 39
# 26    27               Bibibop Asian Grill                 44
# 27    28               Bubbakoo's Burritos                 28
# 28    29                Dos Toros Taqueria                 28
# 29    30                   The Pizza Press                 27
# 30    31                    The Lost Cajun                 20
# 31    32                        Just Salad                 42
# 32    33        Jeni's Splendid Ice Creams                 42
# 33    34                          Boqueria                 27
# 34    35         Quickway Japanese Hibachi                 22
# 35    36                         Surcheros                 22
# 36    37                   Famous Toastery                 40
# 37    38                  Culinary Dropout                 20
# 38    39                     Condado Tacos                 38
# 39    40           The Flying Biscuit Cafe                 29
# 40    41             Blue Sushi Sake Grill                 49
# 41    42                    The Human Bean                 47
# 42    43   Spitz Mediterranean Street Food                 28
# 43    44                      Tacos 4 Life                 25
# 44    45    Pita Mediterranean Street Food                 38
# 45    46                       LA Crawfish                 48
# 46    47                            &pizza                 45
# 47    48               Super Duper Burgers                 39
# 48    49                   StoneFire Grill                 31
# 49    50  Gus's World Famous Fried Chicken                 44
#
#                 City     State
# 0            Seattle     Wash.
# 1          Charlotte      N.C.
# 2   Huntington Beach    Calif.
# 3         Wilmington      N.C.
# 4             Irvine    Calif.
# 5             Belmar      N.J.
# 6          Blue Bell       Pa.
# 7           New York      N.Y.
# 8        Yorba Linda    Calif.
# 9         Louisville       Ky.
# 10       Spartanburg      S.C.
# 11          Pasadena    Calif.
# 12            Denver     Colo.
# 13          New York      N.Y.
# 14             Plano     Texas
# 15         Kettering      Ohio
# 16     San Francisco    Calif.
# 17         San Ramon    Calif.
# 18           Orlando      Fla.
# 19       Orange Park      Fla.
# 20             Doral      Fla.
# 21     Mechanicsburg       Pa.
# 22          New York      N.Y.
# 23          New York      N.Y.
# 24          New York      N.Y.
# 25          Olivette       Mo.
# 26          Columbus      Ohio
# 27     Wall Township      N.J.
# 28          New York      N.Y.
# 29           Anaheim    Calif.
# 30            Frisco     Texas
# 31          New York      N.Y.
# 32          Columbus      Ohio
# 33          New York      N.Y.
# 34           Fairfax       Va.
# 35           Douglas       Ga.
# 36         Charlotte      N.C.
# 37        Scottsdale     Ariz.
# 38          Columbus      Ohio
# 39           Atlanta       Ga.
# 40             Omaha      Neb.
# 41           Medford      Ore.
# 42       Los Angeles    Calif.
# 43            Conway      Ark.
# 44          Fairburn       Ga.
# 45           McAllen     Texas
# 46        Washington      D.C.
# 47     San Francisco    Calif.
# 48      Agoura Hills    Calif.
# 49           Memphis     Tenn.

# %%
ind100_df
# Out:
#     Rank                           Restaurant  Sales_in_millions        City  \
# 0      1             Carmine's (Times Square)          39.080335    New York
# 1      2                The Boathouse Orlando          35.218364    Orlando
# 2      3                     Old Ebbitt Grill          29.104017  Washington
# 3      4  LAVO Italian Restaurant & Nightclub          26.916180    New York
# 4      5             Bryant Park Grill & Cafe          26.900000    New York
# ..   ...                                  ...                ...         ...
# 95    96                 George's at the Cove          12.194000    La Jolla
# 96    97                            Le Coucou          12.187523    New York
# 97    98                              Mi Vida          12.032014  Washington
# 98    99                               Upland          11.965564    New York
# 99   100               Virgil's Real Barbecue          11.391678   Las Vegas
#
#      State
# 0     N.Y.
# 1     Fla.
# 2     D.C.
# 3     N.Y.
# 4     N.Y.
# ..     ...
# 95  Calif.
# 96    N.Y.
# 97    D.C.
# 98    N.Y.
# 99    Nev.
#
# [100 rows x 5 columns]

# %%
# Paso 5. Combinar el dataframe Future50 y el dataframe Ind100. Guardar el resultado en la variable top150_df
ind100_df['Sales_in_millions'] = ind100_df['Sales_in_millions'].astype(int)
top150_df = pd.merge(future50_df, ind100_df,on=['Sales_in_millions'])
top150_df
# Out:
#     Rank_x               Restaurant_x  Sales_in_millions            City_x  \
# 0        1                 Evergreens                 24           Seattle
# 1        1                 Evergreens                 24           Seattle
# 2        1                 Evergreens                 24           Seattle
# 3        1                 Evergreens                 24           Seattle
# 4        7           The Simple Greek                 24         Blue Bell
# 5        7           The Simple Greek                 24         Blue Bell
# 6        7           The Simple Greek                 24         Blue Bell
# 7        7           The Simple Greek                 24         Blue Bell
# 8        9                 Creamistry                 24       Yorba Linda
# 9        9                 Creamistry                 24       Yorba Linda
# 10       9                 Creamistry                 24       Yorba Linda
# 11       9                 Creamistry                 24       Yorba Linda
# 12      16          Rapid Fired Pizza                 24         Kettering
# 13      16          Rapid Fired Pizza                 24         Kettering
# 14      16          Rapid Fired Pizza                 24         Kettering
# 15      16          Rapid Fired Pizza                 24         Kettering
# 16       3                   Slapfish                 21  Huntington Beach
# 17       3                   Slapfish                 21  Huntington Beach
# 18      15          Original ChopShop                 21             Plano
# 19      15          Original ChopShop                 21             Plano
# 20       4                 Clean Eatz                 25        Wilmington
# 21       4                 Clean Eatz                 25        Wilmington
# 22      44               Tacos 4 Life                 25            Conway
# 23      44               Tacos 4 Life                 25            Conway
# 24       6                Playa Bowls                 39            Belmar
# 25      12                   Dog Haus                 39          Pasadena
# 26      20   Maple Street Biscuit Co.                 39       Orange Park
# 27      26       Sugarfire Smokehouse                 39          Olivette
# 28      48        Super Duper Burgers                 39     San Francisco
# 29       8                  Melt Shop                 20          New York
# 30       8                  Melt Shop                 20          New York
# 31      31             The Lost Cajun                 20            Frisco
# 32      31             The Lost Cajun                 20            Frisco
# 33      38           Culinary Dropout                 20        Scottsdale
# 34      38           Culinary Dropout                 20        Scottsdale
# 35      10       Joella's Hot Chicken                 29        Louisville
# 36      40    The Flying Biscuit Cafe                 29           Atlanta
# 37      19  Hawkers Asian Street Fare                 22           Orlando
# 38      19  Hawkers Asian Street Fare                 22           Orlando
# 39      19  Hawkers Asian Street Fare                 22           Orlando
# 40      19  Hawkers Asian Street Fare                 22           Orlando
# 41      19  Hawkers Asian Street Fare                 22           Orlando
# 42      19  Hawkers Asian Street Fare                 22           Orlando
# 43      35  Quickway Japanese Hibachi                 22           Fairfax
# 44      35  Quickway Japanese Hibachi                 22           Fairfax
# 45      35  Quickway Japanese Hibachi                 22           Fairfax
# 46      35  Quickway Japanese Hibachi                 22           Fairfax
# 47      35  Quickway Japanese Hibachi                 22           Fairfax
# 48      35  Quickway Japanese Hibachi                 22           Fairfax
# 49      36                  Surcheros                 22           Douglas
# 50      36                  Surcheros                 22           Douglas
# 51      36                  Surcheros                 22           Douglas
# 52      36                  Surcheros                 22           Douglas
# 53      36                  Surcheros                 22           Douglas
# 54      36                  Surcheros                 22           Douglas
# 55      23            The Little Beet                 23          New York
# 56      23            The Little Beet                 23          New York
# 57      23            The Little Beet                 23          New York
# 58      23            The Little Beet                 23          New York
#
#      State_x  Rank_y                             Restaurant_y        City_y  \
# 0      Wash.       8                              Maple & Ash       Chicago
# 1      Wash.       9                                Balthazar      New York
# 2      Wash.      10                        Smith & Wollensky      New York
# 3      Wash.      11                               Angus Barn       Raleigh
# 4        Pa.       8                              Maple & Ash       Chicago
# 5        Pa.       9                                Balthazar      New York
# 6        Pa.      10                        Smith & Wollensky      New York
# 7        Pa.      11                               Angus Barn       Raleigh
# 8     Calif.       8                              Maple & Ash       Chicago
# 9     Calif.       9                                Balthazar      New York
# 10    Calif.      10                        Smith & Wollensky      New York
# 11    Calif.      11                               Angus Barn       Raleigh
# 12      Ohio       8                              Maple & Ash       Chicago
# 13      Ohio       9                                Balthazar      New York
# 14      Ohio      10                        Smith & Wollensky      New York
# 15      Ohio      11                               Angus Barn       Raleigh
# 16    Calif.      22                            SW Steakhouse     Las Vegas
# 17    Calif.      23                     St. Elmo Steak House  Indianapolis
# 18     Texas      22                            SW Steakhouse     Las Vegas
# 19     Texas      23                     St. Elmo Steak House  Indianapolis
# 20      N.C.       6                 Gibsons Bar & Steakhouse       Chicago
# 21      N.C.       7           Top of the World at the STRAT      Las Vegas
# 22      Ark.       6                 Gibsons Bar & Steakhouse       Chicago
# 23      Ark.       7           Top of the World at the STRAT      Las Vegas
# 24      N.J.       1                 Carmine's (Times Square)      New York
# 25    Calif.       1                 Carmine's (Times Square)      New York
# 26      Fla.       1                 Carmine's (Times Square)      New York
# 27       Mo.       1                 Carmine's (Times Square)      New York
# 28    Calif.       1                 Carmine's (Times Square)      New York
# 29      N.Y.      24                                RPM Steak       Chicago
# 30      N.Y.      25                             Mon Ami Gabi     Las Vegas
# 31     Texas      24                                RPM Steak       Chicago
# 32     Texas      25                             Mon Ami Gabi     Las Vegas
# 33     Ariz.      24                                RPM Steak       Chicago
# 34     Ariz.      25                             Mon Ami Gabi     Las Vegas
# 35       Ky.       3                         Old Ebbitt Grill    Washington
# 36       Ga.       3                         Old Ebbitt Grill    Washington
# 37      Fla.      16  Joe's Seafood, Prime Steak & Stone Crab       Chicago
# 38      Fla.      17  Joe's Seafood, Prime Steak & Stone Crab     Las Vegas
# 39      Fla.      18                           Gibsons Italia       Chicago
# 40      Fla.      19                                   Komodo         Miami
# 41      Fla.      20                                 Buddakan      New York
# 42      Fla.      21               Bazaar Meat by Jose Andres     Las Vegas
# 43       Va.      16  Joe's Seafood, Prime Steak & Stone Crab       Chicago
# 44       Va.      17  Joe's Seafood, Prime Steak & Stone Crab     Las Vegas
# 45       Va.      18                           Gibsons Italia       Chicago
# 46       Va.      19                                   Komodo         Miami
# 47       Va.      20                                 Buddakan      New York
# 48       Va.      21               Bazaar Meat by Jose Andres     Las Vegas
# 49       Ga.      16  Joe's Seafood, Prime Steak & Stone Crab       Chicago
# 50       Ga.      17  Joe's Seafood, Prime Steak & Stone Crab     Las Vegas
# 51       Ga.      18                           Gibsons Italia       Chicago
# 52       Ga.      19                                   Komodo         Miami
# 53       Ga.      20                                 Buddakan      New York
# 54       Ga.      21               Bazaar Meat by Jose Andres     Las Vegas
# 55      N.Y.      12                                Prime 112   Miami Beach
# 56      N.Y.      13  Joe's Seafood, Prime Steak & Stone Crab    Washington
# 57      N.Y.      14                  Junior's (Times Square)      New York
# 58      N.Y.      15                             The Hamilton    Washington
#
#    State_y
# 0     Ill.
# 1     N.Y.
# 2     N.Y.
# 3     N.C.
# 4     Ill.
# 5     N.Y.
# 6     N.Y.
# 7     N.C.
# 8     Ill.
# 9     N.Y.
# 10    N.Y.
# 11    N.C.
# 12    Ill.
# 13    N.Y.
# 14    N.Y.
# 15    N.C.
# 16    Nev.
# 17    Ind.
# 18    Nev.
# 19    Ind.
# 20    Ill.
# 21    Nev.
# 22    Ill.
# 23    Nev.
# 24    N.Y.
# 25    N.Y.
# 26    N.Y.
# 27    N.Y.
# 28    N.Y.
# 29    Ill.
# 30    Nev.
# 31    Ill.
# 32    Nev.
# 33    Ill.
# 34    Nev.
# 35    D.C.
# 36    D.C.
# 37    Ill.
# 38    Nev.
# 39    Ill.
# 40    Fla.
# 41    N.Y.
# 42    Nev.
# 43    Ill.
# 44    Nev.
# 45    Ill.
# 46    Fla.
# 47    N.Y.
# 48    Nev.
# 49    Ill.
# 50    Nev.
# 51    Ill.
# 52    Fla.
# 53    N.Y.
# 54    Nev.
# 55    Fla.
# 56    D.C.
# 57    N.Y.
# 58    D.C.

# %%
# Paso 6. Crear una nueva columna que clasifica según la ubicación
# Ordenar por Sales de manera descendente
top150_df = top150_df.sort_values(by='Sales_in_millions', ascending=False)
# Restablecer el índice para mostrar el nuevo rango para location df
top150_df = top150_df.reset_index()
# Hacer que el índice empiece en 1
top150_df.index = np.arange(1, len(top150_df) + 1)
# Renombrar el índice de Rank para mostrar el nuevo rango
top150_df.index.names = ['Rank']
# Eliminar columnas innecesarias
top150_df = top150_df.drop(columns = ['index', 'Rank_x', 'Rank_y'])
top150_df

# %% [markdown]
# ## Cargar DataFrames en la Base de Datos

# %%
#Rellena la siguiente variable con tu nombre y apellido (Todo junto y sin espacios)
nombreBD = 'adrianfreire'
linkConexion = 'mysql+mysqlconnector://alumno:385bd4cf713a8a36@13.39.109.107/' + nombreBD
#Establecemos la conexión
engine = create_engine(linkConexion)

# %%
if not database_exists(engine.url):
    create_database(engine.url)

# %%
# Sube el dataframes a sql para future50df.
# PISTA: Usa la funcion to_sql() de sqlalchemy
future50_df.to_sql(name='future50', con=engine, if_exists='replace', index=False)
# Out:
# -1

# %%
# Sube el dataframes a sql para ind100 df.
ind100_df.to_sql(name='ind100', con=engine, if_exists='replace', index=False)
# Out:
# -1

# %%
# Sube el dataframes a sql para top250 df.
top250.to_sql(name='top250', con=engine, if_exists='replace', index=False)
# Out:
# -1

# %%
# Sube el dataframes a sql para top150 df.
top150_df.to_sql(name='top150', con=engine, if_exists='replace', index=False)
# Out:
# -1

# %% [markdown]
# ### Confirmar que los datos han sido añadidos consultando la tabla Top150

# %%
# Haz un select de la tabla top150
query = 'SELECT * from top150'
df  = pd.read_sql(query, con = engine )
df
# Out:
#     Rank               Restaurant_x  Sales_in_millions            City_x  \
# 0      1        Super Duper Burgers                 39     San Francisco
# 1      3   Maple Street Biscuit Co.                 39       Orange Park
# 2      4                   Dog Haus                 39          Pasadena
# 3      5                Playa Bowls                 39            Belmar
# 4      2       Sugarfire Smokehouse                 39          Olivette
# 5      6    The Flying Biscuit Cafe                 29           Atlanta
# 6      7       Joella's Hot Chicken                 29        Louisville
# 7     11                 Clean Eatz                 25        Wilmington
# 8     10                 Clean Eatz                 25        Wilmington
# 9      9               Tacos 4 Life                 25            Conway
# 10     8               Tacos 4 Life                 25            Conway
# 11    20                 Creamistry                 24       Yorba Linda
# 12    27                 Evergreens                 24           Seattle
# 13    26                 Evergreens                 24           Seattle
# 14    25                 Evergreens                 24           Seattle
# 15    24           The Simple Greek                 24         Blue Bell
# 16    23           The Simple Greek                 24         Blue Bell
# 17    22           The Simple Greek                 24         Blue Bell
# 18    21           The Simple Greek                 24         Blue Bell
# 19    15          Rapid Fired Pizza                 24         Kettering
# 20    19                 Creamistry                 24       Yorba Linda
# 21    18                 Creamistry                 24       Yorba Linda
# 22    17                 Creamistry                 24       Yorba Linda
# 23    16          Rapid Fired Pizza                 24         Kettering
# 24    14          Rapid Fired Pizza                 24         Kettering
# 25    13          Rapid Fired Pizza                 24         Kettering
# 26    12                 Evergreens                 24           Seattle
# 27    31            The Little Beet                 23          New York
# 28    30            The Little Beet                 23          New York
# 29    29            The Little Beet                 23          New York
# 30    28            The Little Beet                 23          New York
# 31    41  Quickway Japanese Hibachi                 22           Fairfax
# 32    49                  Surcheros                 22           Douglas
# 33    48  Hawkers Asian Street Fare                 22           Orlando
# 34    47  Hawkers Asian Street Fare                 22           Orlando
# 35    46  Hawkers Asian Street Fare                 22           Orlando
# 36    44  Hawkers Asian Street Fare                 22           Orlando
# 37    43  Hawkers Asian Street Fare                 22           Orlando
# 38    42  Quickway Japanese Hibachi                 22           Fairfax
# 39    45  Hawkers Asian Street Fare                 22           Orlando
# 40    40                  Surcheros                 22           Douglas
# 41    38  Quickway Japanese Hibachi                 22           Fairfax
# 42    37  Quickway Japanese Hibachi                 22           Fairfax
# 43    36                  Surcheros                 22           Douglas
# 44    35                  Surcheros                 22           Douglas
# 45    34                  Surcheros                 22           Douglas
# 46    33                  Surcheros                 22           Douglas
# 47    32  Quickway Japanese Hibachi                 22           Fairfax
# 48    39  Quickway Japanese Hibachi                 22           Fairfax
# 49    52                   Slapfish                 21  Huntington Beach
# 50    53                   Slapfish                 21  Huntington Beach
# 51    50          Original ChopShop                 21             Plano
# 52    51          Original ChopShop                 21             Plano
# 53    54             The Lost Cajun                 20            Frisco
# 54    55             The Lost Cajun                 20            Frisco
# 55    56                  Melt Shop                 20          New York
# 56    57           Culinary Dropout                 20        Scottsdale
# 57    58           Culinary Dropout                 20        Scottsdale
# 58    59                  Melt Shop                 20          New York
#
#      State_x                             Restaurant_y        City_y State_y
# 0     Calif.                 Carmine's (Times Square)      New York    N.Y.
# 1       Fla.                 Carmine's (Times Square)      New York    N.Y.
# 2     Calif.                 Carmine's (Times Square)      New York    N.Y.
# 3       N.J.                 Carmine's (Times Square)      New York    N.Y.
# 4        Mo.                 Carmine's (Times Square)      New York    N.Y.
# 5        Ga.                         Old Ebbitt Grill    Washington    D.C.
# 6        Ky.                         Old Ebbitt Grill    Washington    D.C.
# 7       N.C.                 Gibsons Bar & Steakhouse       Chicago    Ill.
# 8       N.C.           Top of the World at the STRAT      Las Vegas    Nev.
# 9       Ark.                 Gibsons Bar & Steakhouse       Chicago    Ill.
# 10      Ark.           Top of the World at the STRAT      Las Vegas    Nev.
# 11    Calif.                              Maple & Ash       Chicago    Ill.
# 12     Wash.                                Balthazar      New York    N.Y.
# 13     Wash.                        Smith & Wollensky      New York    N.Y.
# 14     Wash.                               Angus Barn       Raleigh    N.C.
# 15       Pa.                              Maple & Ash       Chicago    Ill.
# 16       Pa.                                Balthazar      New York    N.Y.
# 17       Pa.                        Smith & Wollensky      New York    N.Y.
# 18       Pa.                               Angus Barn       Raleigh    N.C.
# 19      Ohio                                Balthazar      New York    N.Y.
# 20    Calif.                                Balthazar      New York    N.Y.
# 21    Calif.                        Smith & Wollensky      New York    N.Y.
# 22    Calif.                               Angus Barn       Raleigh    N.C.
# 23      Ohio                              Maple & Ash       Chicago    Ill.
# 24      Ohio                               Angus Barn       Raleigh    N.C.
# 25      Ohio                        Smith & Wollensky      New York    N.Y.
# 26     Wash.                              Maple & Ash       Chicago    Ill.
# 27      N.Y.                             The Hamilton    Washington    D.C.
# 28      N.Y.                                Prime 112   Miami Beach    Fla.
# 29      N.Y.  Joe's Seafood, Prime Steak & Stone Crab    Washington    D.C.
# 30      N.Y.                  Junior's (Times Square)      New York    N.Y.
# 31       Va.  Joe's Seafood, Prime Steak & Stone Crab     Las Vegas    Nev.
# 32       Ga.                                   Komodo         Miami    Fla.
# 33      Fla.  Joe's Seafood, Prime Steak & Stone Crab       Chicago    Ill.
# 34      Fla.  Joe's Seafood, Prime Steak & Stone Crab     Las Vegas    Nev.
# 35      Fla.                           Gibsons Italia       Chicago    Ill.
# 36      Fla.                                 Buddakan      New York    N.Y.
# 37      Fla.               Bazaar Meat by Jose Andres     Las Vegas    Nev.
# 38       Va.  Joe's Seafood, Prime Steak & Stone Crab       Chicago    Ill.
# 39      Fla.                                   Komodo         Miami    Fla.
# 40       Ga.               Bazaar Meat by Jose Andres     Las Vegas    Nev.
# 41       Va.                                 Buddakan      New York    N.Y.
# 42       Va.               Bazaar Meat by Jose Andres     Las Vegas    Nev.
# 43       Ga.  Joe's Seafood, Prime Steak & Stone Crab       Chicago    Ill.
# 44       Ga.  Joe's Seafood, Prime Steak & Stone Crab     Las Vegas    Nev.
# 45       Ga.                           Gibsons Italia       Chicago    Ill.
# 46       Ga.                                 Buddakan      New York    N.Y.
# 47       Va.                           Gibsons Italia       Chicago    Ill.
# 48       Va.                                   Komodo         Miami    Fla.
# 49    Calif.                     St. Elmo Steak House  Indianapolis    Ind.
# 50    Calif.                            SW Steakhouse     Las Vegas    Nev.
# 51     Texas                     St. Elmo Steak House  Indianapolis    Ind.
# 52     Texas                            SW Steakhouse     Las Vegas    Nev.
# 53     Texas                                RPM Steak       Chicago    Ill.
# 54     Texas                             Mon Ami Gabi     Las Vegas    Nev.
# 55      N.Y.                             Mon Ami Gabi     Las Vegas    Nev.
# 56     Ariz.                             Mon Ami Gabi     Las Vegas    Nev.
# 57     Ariz.                                RPM Steak       Chicago    Ill.
# 58      N.Y.                                RPM Steak       Chicago    Ill.

# %%
# Recupera los restaurantes "Virgil's Real Barbecue" de la tabla top150
query = 'SELECT Restaurant_x, Restaurant_y FROM top150 WHERE Restaurant_x LIKE "%Barbecue" AND Restaurant_y LIKE "%%Barbecue"'
df  = pd.read_sql(query, con = engine )
df
# Out:
# Empty DataFrame
# Columns: [Restaurant_x, Restaurant_y]
# Index: []

# %% [markdown]
# ### Resumen
#
# A partir de una fuente de datos opensource en [Kaggle](https://www.kaggle.com/datasets/michau96/restaurant-business-rankings-2020) hemos creado montado ETL. Extraído, procesado y cargado los datos en una BBDD (base de datos).
#
#
# ---
#
#
# ## Obtención de datos
#
# INPUT: 3 archivos CSV con las clasificaciones de los mejores restaurantes de 2020.
#
#
#
# *   Future 50:
# Clasificaciones de los futuros 50 mejores restaurantes.
# *   Independence 100:
# Clasificaciones de los 100 mejores restaurantes independientes de 2020.
# *   Top 250:
# Clasificaciones de los 250 mejores restaurantes de 2020.
#
# Todos los datos se extrajeron de Restaurant Business Online y están basados en informes financieros de la empresa, encuestas, documentos de las franquicias y algoritmos de valoración.
#
# ## Transformación
#
# 1. Cambiamos el nombre a todas las columnas Sales para indicar que las unidades estaban en millones y corregir el dataframe Independence 100 cuya columna Sales no representamos en millones para que hubiera consistencia en las tablas.
# 2. Eliminamos algunas columnas adicionales que no vamos a usar en futuros análisis. Seleccionamos "Content" y "Headquarter" del dataframe top 250 ya que contenían muchos valores NaN y no proporcionaban información útil.
# 3. Agrupamos el dataframe independent 100 por Restaurant para combinar cualquier duplicado dentro de la tabla. Sumamos las columnas "Sales in Millions" y "Meals Served", calculamos el promedio de la columna "Average Check" y hacemos un recuento de cada restaurante para que se pueda ver si estaba representado en la tabla original varias veces. Finalmente, ordenamos este nuevo dataframe por Sales in Millions en orden descendente para ver los nuevos restaurantes mejor clasificados.
# 4. Para mantener la integridad de nuestro dataframe Future 50, hacemos una copia. Nuestro objetivo es fusionar el dataframe con la lista Independent 100 en función de los detalles de la ubicación.
# 5. Usando el dataframe copiado, separamos los valores de "Location" en dos columnas separadas ("City" y "State") y los almacenamos en un nuevo dataframe.
# 6. Para agregar los datos de "City" y "State" a nuestra copia original del dataframe Future 50, creamos las nuevas columnas y luego insertamos los valores separados en el paso anterior. Finalmente, eliminamos las columnas innecesarias.
# 7. Para mantener la integridad de nuestro dataframe Independent 100, hacemos una copia y luego eliminamos las columnas innecesarias. Hacemos que los dataframes copiados de Future 50 e Independent 100 tengan las mismas columnas para combinarlos fácilmente. Finalmente concatenamos los dos dataframes para hacer una lista del top 150.
# 8. Cogemos el dataframe Top 150 y ordenamos las filas por Sales in Millions. A continuación, reiniciamos el índice y lo hacemos contar desde 1 para mostrar la nueva clasificación. Finalmente, cambiamos el nombre del índice a Rank y eliminamos las columnas innecesarias.
#
# ##Subida a la base de datos
#
# Una vez habiendo hecho un procesado de los datos nos disponemos a hacer los inserts a la BBDD.
# 1. Nos conectamos a la base de datos.
# 2. Y, por último, subimos nuestros dataframes para que se almacenen en tablas.
