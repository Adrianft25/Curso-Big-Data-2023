# %% [markdown]
# <a href="https://colab.research.google.com/github/Adrianft25/Curso-Big-Data-2023/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Ejercicio 1
#
# Obtener las primeras `3` filas de un objeto `DataFrame`.

# %%
#Datos
nombre = ['Oliva', 'Daniela', 'Juan', 'Germán', 'Edward', 'Alex', 'Julio', 
          'Edgar', 'Angie', 'Irlesa']
puntaje = [11.5, 8, 15.5, np.nan, 8, 19, 13.5, np.nan, 8, 18]
intentos = [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]
califico = ['Sí', 'No', 'Sí', 'No', 'No', 'Sí', 'Sí', 'No', 'No', 'Sí']

indices = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

jugadores = {'nombre': nombre, 'puntaje': puntaje, 'intentos': intentos, 
             'califico': califico}

df = pd.DataFrame(data=jugadores, index=indices)

df
# Out:
#     nombre  puntaje  intentos califico
# a    Oliva     11.5         1       Sí
# b  Daniela      8.0         3       No
# c     Juan     15.5         2       Sí
# d   Germán      NaN         3       No
# e   Edward      8.0         2       No
# f     Alex     19.0         3       Sí
# g    Julio     13.5         1       Sí
# h    Edgar      NaN         1       No
# i    Angie      8.0         2       No
# j   Irlesa     18.0         1       Sí

# %%
#Solución, aquí tu respuesta
df.head(3)
# Out:
#     nombre  puntaje  intentos califico
# a    Oliva     11.5         1       Sí
# b  Daniela      8.0         3       No
# c     Juan     15.5         2       Sí

# %% [markdown]
# # Ejercicio 2
#
# Obtener las últimas `3` filas de un objeto `DataFrame`.

# %%
#Datos
nombre = ['Oliva', 'Daniela', 'Juan', 'Germán', 'Edward', 'Alex', 'Julio', 
          'Edgar', 'Angie', 'Irlesa']
puntaje = [11.5, 8, 15.5, np.nan, 8, 19, 13.5, np.nan, 8, 18]
intentos = [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]
califico = ['Sí', 'No', 'Sí', 'No', 'No', 'Sí', 'Sí', 'No', 'No', 'Sí']

indices = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

jugadores = {'nombre': nombre, 'puntaje': puntaje, 'intentos': intentos, 
             'califico': califico}

df = pd.DataFrame(data=jugadores, index=indices)

df
# Out:
#     nombre  puntaje  intentos califico
# a    Oliva     11.5         1       Sí
# b  Daniela      8.0         3       No
# c     Juan     15.5         2       Sí
# d   Germán      NaN         3       No
# e   Edward      8.0         2       No
# f     Alex     19.0         3       Sí
# g    Julio     13.5         1       Sí
# h    Edgar      NaN         1       No
# i    Angie      8.0         2       No
# j   Irlesa     18.0         1       Sí

# %%
#Solución
df.tail(3)
# Out:
#    nombre  puntaje  intentos califico
# h   Edgar      NaN         1       No
# i   Angie      8.0         2       No
# j  Irlesa     18.0         1       Sí

# %% [markdown]
# # Ejercicio 3
#
# Seleccionar las columnas ['nombre', 'califico'] de un objeto `DataFrame`.

# %%
nombre = ['Oliva', 'Daniela', 'Juan', 'Germán', 'Edward', 'Alex', 'Julio', 
          'Edgar', 'Angie', 'Irlesa']
puntaje = [11.5, 8, 15.5, np.nan, 8, 19, 13.5, np.nan, 8, 18]
intentos = [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]
califico = ['Sí', 'No', 'Sí', 'No', 'No', 'Sí', 'Sí', 'No', 'No', 'Sí']

indices = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

jugadores = {'nombre': nombre, 'puntaje': puntaje, 'intentos': intentos, 
             'califico': califico}

df = pd.DataFrame(data=jugadores, index=indices)

df

# %%
df[['nombre','califico']]
# Out:
#     nombre califico
# a    Oliva       Sí
# b  Daniela       No
# c     Juan       Sí
# d   Germán       No
# e   Edward       No
# f     Alex       Sí
# g    Julio       Sí
# h    Edgar       No
# i    Angie       No
# j   Irlesa       Sí

# %% [markdown]
# # Ejercicio 4
#
# Comprobar si este objeto `DataFrame` está vacío con `empty`.

# %%
df = pd.DataFrame({'X': []})

df

# %%
df.empty
# Out:
# False

# %% [markdown]
# # Ejercicio 5
#
# Crear un objeto `DataFrame` a partir de objetos `Series`.

# %%
#Partimos de dos series
nombres = pd.Series(['Edward', 'Germán', 'Daniela'])
edades = pd.Series([27, 23, 19])

# %%
#1. Metemos las series en un diccionario
diccionario = {'nombres': nombres.to_dict(), 'edades': edades.to_dict()}
#2. Metemos el diccionario dentro de un dataframe
df = pd.DataFrame.from_dict(diccionario)
df
# Out:
#    nombres  edades
# 0   Edward      27
# 1   Germán      23
# 2  Daniela      19

# %% [markdown]
# # Ejercicio 6
#
# Determinar los datos en un `DataFrame` que son nulos (NaN).

# %%
nombres = ['Edward', 'Daniela', 'Germán']
edades = [5, 6, np.nan]
fecha_nacimiento = [pd.Timestamp('1990-01-03'), None, np.nan]

personas = {'nombre': nombres, 'edad': edades, 'fecha_nacimiento': fecha_nacimiento}

df = pd.DataFrame(data=personas)

df.isnull()
# Out:
#    nombre   edad  fecha_nacimiento
# 0   False  False             False
# 1   False  False              True
# 2   False   True              True

# %% [markdown]
# # Ejercicio 7
#
# Modificar un valor o entrada específico de un objeto `DataFrame` usando `loc`.

# %%
datos = {'X': [1, 2, 3, 4, 5], 'Y': [5, 4, 3, 2, 1], 'Z': [2, 3, 5, 7, 11]}

indices = ['a', 'b', 'c', 'd', 'e']

df = pd.DataFrame(data=datos, index=indices)

df
# Out:
#    X  Y   Z
# a  1  5   2
# b  2  4   3
# c  3  3   5
# d  4  2   7
# e  5  1  11

# %%
df.loc['b', 'Y'] = 37
df
# Out:
#    X   Y   Z
# a  1   5   2
# b  2  37   3
# c  3   3   5
# d  4   2   7
# e  5   1  11

# %% [markdown]
# # Ejercicio 8
#
# Acceder a un valor o entrada específico de un objeto `DataFrame` usando `loc`.

# %%
datos = {'X': [1, 2, 3, 4, 5], 'Y': [5, 4, 3, 2, 1], 'Z': [2, 3, 5, 7, 11]}

indices = ['a', 'b', 'c', 'd', 'e']

df = pd.DataFrame(data=datos, index=indices)

valor = df.loc['e', 'Z']
valor
# Out:
# 11

# %% [markdown]
# # Ejercicio 9
#
# Sumar los valores de la columna intentos con `sum`.

# %%
nombre = ['Oliva', 'Daniela', 'Juan', 'Germán', 'Edward', 'Alex', 'Julio', 
          'Edgar', 'Angie', 'Irlesa']
puntaje = [11.5, 8, 15.5, np.nan, 8, 19, 13.5, np.nan, 8, 18]
intentos = [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]
califico = ['Sí', 'No', 'Sí', 'No', 'No', 'Sí', 'Sí', 'No', 'No', 'Sí']

indices = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

jugadores = {'nombre': nombre, 'puntaje': puntaje, 'intentos': intentos, 
             'califico': califico}

df = pd.DataFrame(data=jugadores, index=indices)

df

# %%
suma = df['intentos'].sum()
suma
# Out:
# 19

# %% [markdown]
# # Ejercicio 10 (Opcional)
#
#  Agregar una nueva fila a un objeto `DataFrame` por medio de `loc`.

# %%
nombre = ['Oliva', 'Daniela', 'Juan', 'Germán', 'Edward', 'Alex', 'Julio', 
          'Edgar', 'Angie', 'Irlesa']
puntaje = [11.5, 8, 15.5, np.nan, 8, 19, 13.5, np.nan, 8, 18]
intentos = [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]
califico = ['Sí', 'No', 'Sí', 'No', 'No', 'Sí', 'Sí', 'No', 'No', 'Sí']

indices = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

jugadores = {'nombre': nombre, 'puntaje': puntaje, 'intentos': intentos, 
             'califico': califico}

df = pd.DataFrame(data=jugadores, index=indices)

df
# Out:
#     nombre  puntaje  intentos califico
# a    Oliva     11.5         1       Sí
# b  Daniela      8.0         3       No
# c     Juan     15.5         2       Sí
# d   Germán      NaN         3       No
# e   Edward      8.0         2       No
# f     Alex     19.0         3       Sí
# g    Julio     13.5         1       Sí
# h    Edgar      NaN         1       No
# i    Angie      8.0         2       No
# j   Irlesa     18.0         1       Sí

# %%
df.loc[len(df)] = {"nombre": "prueba", "puntaje": 123.0, "intentos": 5, "califico": "No"}
df
# Out:
#      nombre  puntaje  intentos califico
# a     Oliva     11.5         1       Sí
# b   Daniela      8.0         3       No
# c      Juan     15.5         2       Sí
# d    Germán      NaN         3       No
# e    Edward      8.0         2       No
# f      Alex     19.0         3       Sí
# g     Julio     13.5         1       Sí
# h     Edgar      NaN         1       No
# i     Angie      8.0         2       No
# j    Irlesa     18.0         1       Sí
# 10   prueba    123.0         5       No

# %% [markdown]
# # Ejercicio 11
#
# Eliminar una fila de un `DataFrame` con la función `drop`.

# %%
nombre = ['Oliva', 'Daniela', 'Juan', 'Germán', 'Edward', 'Alex', 'Julio', 
          'Edgar', 'Angie', 'Irlesa']
puntaje = [11.5, 8, 15.5, np.nan, 8, 19, 13.5, np.nan, 8, 18]
intentos = [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]
califico = ['Sí', 'No', 'Sí', 'No', 'No', 'Sí', 'Sí', 'No', 'No', 'Sí']

indices = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

jugadores = {'nombre': nombre, 'puntaje': puntaje, 'intentos': intentos, 
             'califico': califico}

df = pd.DataFrame(data=jugadores, index=indices)

df
# Out:
#     nombre  puntaje  intentos califico
# a    Oliva     11.5         1       Sí
# b  Daniela      8.0         3       No
# c     Juan     15.5         2       Sí
# d   Germán      NaN         3       No
# e   Edward      8.0         2       No
# f     Alex     19.0         3       Sí
# g    Julio     13.5         1       Sí
# h    Edgar      NaN         1       No
# i    Angie      8.0         2       No
# j   Irlesa     18.0         1       Sí

# %%
df.drop('califico', axis=1, inplace=True)
df
# Out:
#     nombre  puntaje  intentos
# a    Oliva     11.5         1
# b  Daniela      8.0         3
# c     Juan     15.5         2
# d   Germán      NaN         3
# e   Edward      8.0         2
# f     Alex     19.0         3
# g    Julio     13.5         1
# h    Edgar      NaN         1
# i    Angie      8.0         2
# j   Irlesa     18.0         1

# %% [markdown]
# # Ejercicio 12
#
# Mostrar los n primeros y últimos registros de un objeto `DataFrame` con `head` y `tail`.

# %%
datos_1 = list(range(1, 101))
datos_2 = list(range(1, 101))

df = pd.DataFrame({'A': datos_1, 'B': datos_2})

df
# Out:
#       A    B
# 0     1    1
# 1     2    2
# 2     3    3
# 3     4    4
# 4     5    5
# ..  ...  ...
# 95   96   96
# 96   97   97
# 97   98   98
# 98   99   99
# 99  100  100
#
# [100 rows x 2 columns]

# %%
df.head(5)
# Out:
#    A  B
# 0  1  1
# 1  2  2
# 2  3  3
# 3  4  4
# 4  5  5

# %%
df.tail(5)
# Out:
#       A    B
# 95   96   96
# 96   97   97
# 97   98   98
# 98   99   99
# 99  100  100

# %% [markdown]
# # Ejercicio 13
#
# Agregar una nueva columna a un `DataFrame` con notación de slicing.
#
# `df['nombre_nueva_columna'] = valores`

# %%
nombre = ['Oliva', 'Daniela', 'Juan', 'Germán', 'Edward', 'Alex', 'Julio', 
          'Edgar', 'Angie', 'Irlesa']
puntaje = [11.5, 8, 15.5, np.nan, 8, 19, 13.5, np.nan, 8, 18]
intentos = [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]
califico = ['Sí', 'No', 'Sí', 'No', 'No', 'Sí', 'Sí', 'No', 'No', 'Sí']

indices = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

jugadores = {'nombre': nombre, 'puntaje': puntaje, 'intentos': intentos, 
             'califico': califico}

df = pd.DataFrame(data=jugadores, index=indices)

df
# Out:
#     nombre  puntaje  intentos califico
# a    Oliva     11.5         1       Sí
# b  Daniela      8.0         3       No
# c     Juan     15.5         2       Sí
# d   Germán      NaN         3       No
# e   Edward      8.0         2       No
# f     Alex     19.0         3       Sí
# g    Julio     13.5         1       Sí
# h    Edgar      NaN         1       No
# i    Angie      8.0         2       No
# j   Irlesa     18.0         1       Sí

# %%
#Valores nueva columna
colores = ['Negro', 'Blanco', 'Azul', 'Verde', 'Rojo', 'Amarillo', 
           'Gris', 'Naranja', 'Lila', 'Café']

df['colores'] = ['Negro', 'Blanco', 'Azul', 'Verde', 'Rojo', 'Amarillo', 
           'Gris', 'Naranja', 'Lila', 'Café']

df
# Out:
#     nombre  puntaje  intentos califico   colores
# a    Oliva     11.5         1       Sí     Negro
# b  Daniela      8.0         3       No    Blanco
# c     Juan     15.5         2       Sí      Azul
# d   Germán      NaN         3       No     Verde
# e   Edward      8.0         2       No      Rojo
# f     Alex     19.0         3       Sí  Amarillo
# g    Julio     13.5         1       Sí      Gris
# h    Edgar      NaN         1       No   Naranja
# i    Angie      8.0         2       No      Lila
# j   Irlesa     18.0         1       Sí      Café

# %% [markdown]
# # Recorrer un df
#
#  Para iterar cada una de las filas de un `DataFrame` utilizamos la función `iterrows`.

# %%
nombre = ['Oliva', 'Daniela', 'Juan', 'Germán', 'Edward', 'Alex', 'Julio', 
          'Edgar', 'Angie', 'Irlesa']
puntaje = [11.5, 8, 15.5, np.nan, 8, 19, 13.5, np.nan, 8, 18]
intentos = [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]
califico = ['Sí', 'No', 'Sí', 'No', 'No', 'Sí', 'Sí', 'No', 'No', 'Sí']

indices = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

jugadores = {'nombre': nombre, 'puntaje': puntaje, 'intentos': intentos, 
             'califico': califico}

df = pd.DataFrame(data=jugadores, index=indices)

df

# %%
for indice, fila in df.iterrows():
    print(fila['nombre'], fila['califico'])

# %% [markdown]
# # Ejercicio 14 (Opcional)
#
# Obtener como una lista Python los nombres de las columnas de un `DataFrame`.

# %%
datos = {'X': [1, 2, 3, 4, 5], 'Y': [5, 4, 3, 2, 1], 'Z': [2, 3, 5, 7, 11]}

df = pd.DataFrame(datos)

df

# %% [markdown]
# # Ejercicio 15
#
# Renombrar las columnas de un objeto `DataFrame` a partir del diccionario dado.

# %%
datos = {'Columna1': [1, 2, 3, 4, 5], 'Columna2': [5, 4, 3, 2, 1], 
         'Columna3': [2, 3, 5, 7, 11]}

indices = ['a', 'b', 'c', 'd', 'e']

df = pd.DataFrame(data=datos, index=indices)

df

# %%
#Diccionario con los nuevos nombres de las columnas
renombrado_columnas = {'Columna1': 'X', 'Columna2': 'Y', 'Columna3': 'Z'}

# %% [markdown]
# # Ejercicio 16
#
# * Guardar los registros de un `DataFrame` en un archivo de formato **CSV**.
# * Prueba a descargarlos en tu PC.

# %%
nombre = ['Oliva', 'Daniela', 'Juan', 'Germán', 'Edward', 'Alex', 'Julio', 
          'Edgar', 'Angie', 'Irlesa']
puntaje = [11.5, 8, 15.5, np.nan, 8, 19, 13.5, np.nan, 8, 18]
intentos = [1, 3, 2, 3, 2, 3, 1, 1, 2, 1]
califico = ['Sí', 'No', 'Sí', 'No', 'No', 'Sí', 'Sí', 'No', 'No', 'Sí']

indices = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

jugadores = {'nombre': nombre, 'puntaje': puntaje, 'intentos': intentos, 
             'califico': califico}

df = pd.DataFrame(data=jugadores, index=indices)

df
# Out:
#     nombre  puntaje  intentos califico
# a    Oliva     11.5         1       Sí
# b  Daniela      8.0         3       No
# c     Juan     15.5         2       Sí
# d   Germán      NaN         3       No
# e   Edward      8.0         2       No
# f     Alex     19.0         3       Sí
# g    Julio     13.5         1       Sí
# h    Edgar      NaN         1       No
# i    Angie      8.0         2       No
# j   Irlesa     18.0         1       Sí
