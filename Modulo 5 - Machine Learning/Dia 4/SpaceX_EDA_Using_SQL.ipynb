# %% [markdown]
# <a href="https://colab.research.google.com/github/Adrianft25/Curso-Big-Data-2023/blob/main/SpaceX_EDA_Using_SQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Etapa 3: Análisis de datos utilizando SQL

# %% [markdown]
# ## Objetivos
#
# En esta práctica subiremos los datos a una base de datos SQL y realizaremos diferentes queries para obtener información sobre los datos

# %%
# !pip install sqlalchemy==1.4.16 --quiet
import pandas as pd
import numpy as np
# !pip install PyMySQL --quiet
import pymysql as pymsql
# !pip install mysql-connector --quiet
import mysql.connector
from sqlalchemy import create_engine
# !pip install sqlalchemy-utils --quiet
from sqlalchemy_utils import database_exists, create_database
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ### Tarea 1: Subir los datos a la base de datos:

# %% [markdown]
# Primero cargamos el archivo de datos `dataset_part_2.csv`.

# %%
df_path = "dataset_part_6.csv"
df = pd.read_csv(df_path)

# %%
#Rellena la siguiente variable con tu nombre y apellido (Todo junto y sin espacios). 
nombreBD = 'adrianfreire'
linkConexion = 'mysql+mysqlconnector://alumno:385bd4cf713a8a36@13.39.109.107/' + nombreBD
#Establecemos la conexión
engine = create_engine(linkConexion)

# %%
if not database_exists(engine.url):
    create_database(engine.url)

# %%
# Añadir el dataframe a sql SPACEXTBL usando la función to_sql().
df.to_sql(name="SPACEXTBL", con=engine, if_exists='replace', index=False)
# Out:
# -1

# %%
query = "select * from SPACEXTBL;"
df  = pd.read_sql(query, con = engine )
df
# Out:
#     FlightNumber        Date BoosterVersion   PayloadMass  \
# 0              1  2010-06-04       Falcon 9   6123.547647
# 1              2  2012-05-22       Falcon 9    525.000000
# 2              3  2013-03-01       Falcon 9    677.000000
# 3              4  2013-09-29       Falcon 9    500.000000
# 4              5  2013-12-03       Falcon 9   3170.000000
# ..           ...         ...            ...           ...
# 85            86  2020-09-03       Falcon 9  15600.000000
# 86            87  2020-10-06       Falcon 9  15600.000000
# 87            88  2020-10-18       Falcon 9  15600.000000
# 88            89  2020-10-24       Falcon 9  15600.000000
# 89            90  2020-11-05       Falcon 9   3681.000000
#
#                       Payload Orbit    LaunchSite LandingOutcome  Flights  \
# 0   Dragon Qualification Unit   LEO  CCSFS SLC 40      None None        1
# 1          COTS Demo Flight 2   LEO  CCSFS SLC 40      None None        1
# 2                       CRS-2   ISS  CCSFS SLC 40      None None        1
# 3                    CASSIOPE    PO   VAFB SLC 4E    False Ocean        1
# 4                       SES-8   GTO  CCSFS SLC 40      None None        1
# ..                        ...   ...           ...            ...      ...
# 85                Starlink-11  VLEO    KSC LC 39A      True ASDS        2
# 86                Starlink-12  VLEO    KSC LC 39A      True ASDS        3
# 87                Starlink-13  VLEO    KSC LC 39A      True ASDS        6
# 88                Starlink-14  VLEO  CCSFS SLC 40      True ASDS        3
# 89   GPS III SV04 (Sacagawea)   MEO  CCSFS SLC 40      True ASDS        1
#
#     GridFins  Reused  Legs                LandingPad  Block  \
# 0          0       0     0                      None    1.0
# 1          0       0     0                      None    1.0
# 2          0       0     0                      None    1.0
# 3          0       0     0                      None    1.0
# 4          0       0     0                      None    1.0
# ..       ...     ...   ...                       ...    ...
# 85         1       1     1  5e9e3032383ecb6bb234e7ca    5.0
# 86         1       1     1  5e9e3032383ecb6bb234e7ca    5.0
# 87         1       1     1  5e9e3032383ecb6bb234e7ca    5.0
# 88         1       1     1  5e9e3033383ecbb9e534e7cc    5.0
# 89         1       0     1  5e9e3032383ecb6bb234e7ca    5.0
#
#                     Customers  Mission_Outcome  ReusedCount Serial  \
# 0                      SpaceX                1            0  B0003
# 1                  NASA(COTS)                1            0  B0005
# 2                  NASA (CRS)                1            0  B0007
# 3                         MDA                1            0  B1003
# 4                         SES                1            0  B1004
# ..                        ...              ...          ...    ...
# 85                     SpaceX                1           12  B1060
# 86                     SpaceX                1           13  B1058
# 87                     SpaceX                1           12  B1051
# 88                     SpaceX                1           12  B1060
# 89  United States Space Force                1            8  B1062
#
#      Longitude   Latitude  Class
# 0   -80.577366  28.561857      0
# 1   -80.577366  28.561857      0
# 2   -80.577366  28.561857      0
# 3  -120.610829  34.632093      0
# 4   -80.577366  28.561857      0
# ..         ...        ...    ...
# 85  -80.603956  28.608058      1
# 86  -80.603956  28.608058      1
# 87  -80.603956  28.608058      1
# 88  -80.577366  28.561857      1
# 89  -80.577366  28.561857      1
#
# [90 rows x 21 columns]

# %% [markdown]
# ## Tarea 2: Queries con SQL

# %% [markdown]
# ### Ejercicio 1
#
# ##### Muestra las diferentes plataformas de lanzamiento:

# %%
#Rellena la variable query con tu consulta
query = """  SELECT DISTINCT launchsite FROM SPACEXTBL """
df  = pd.read_sql(query, con = engine )
df
# Out:
#      launchsite
# 0  CCSFS SLC 40
# 1   VAFB SLC 4E
# 2    KSC LC 39A

# %% [markdown]
# ### Ejercicio 2
#
# ##### Muestra 5 lanzamientos cuya plataforma empiece por 'CCS'

# %%
query = """  SELECT * FROM SPACEXTBL WHERE launchsite LIKE 'CCS%' LIMIT 5 """
df  = pd.read_sql(query, con = engine )
df
# Out:
#    FlightNumber        Date BoosterVersion  PayloadMass  \
# 0             1  2010-06-04       Falcon 9  6123.547647
# 1             2  2012-05-22       Falcon 9   525.000000
# 2             3  2013-03-01       Falcon 9   677.000000
# 3             5  2013-12-03       Falcon 9  3170.000000
# 4             6  2014-01-06       Falcon 9  3325.000000
#
#                      Payload Orbit    LaunchSite LandingOutcome  Flights  \
# 0  Dragon Qualification Unit   LEO  CCSFS SLC 40      None None        1
# 1         COTS Demo Flight 2   LEO  CCSFS SLC 40      None None        1
# 2                      CRS-2   ISS  CCSFS SLC 40      None None        1
# 3                      SES-8   GTO  CCSFS SLC 40      None None        1
# 4                  Thaicom 6   GTO  CCSFS SLC 40      None None        1
#
#    GridFins  Reused  Legs LandingPad  Block   Customers  Mission_Outcome  \
# 0         0       0     0       None    1.0      SpaceX                1
# 1         0       0     0       None    1.0  NASA(COTS)                1
# 2         0       0     0       None    1.0  NASA (CRS)                1
# 3         0       0     0       None    1.0         SES                1
# 4         0       0     0       None    1.0     Thaicom                1
#
#    ReusedCount Serial  Longitude   Latitude  Class
# 0            0  B0003 -80.577366  28.561857      0
# 1            0  B0005 -80.577366  28.561857      0
# 2            0  B0007 -80.577366  28.561857      0
# 3            0  B1004 -80.577366  28.561857      0
# 4            0  B1005 -80.577366  28.561857      0

# %% [markdown]
# ### Ejercicio 3
#
# ##### Mustra el la masa total transportada por los lanzamientos realizados donde el cliente es NASA (CRS)

# %%
query = """  SELECT SUM(payloadmass) AS masa_total FROM SPACEXTBL WHERE customers = 'NASA (CRS)' """
df  = pd.read_sql(query, con = engine )
df
# Out:
#    masa_total
# 0     47094.7

# %% [markdown]
# ### Ejercicio 4
#
# ##### Muestra la masa media tranportada por lanzamientos con serie que comienza por B1

# %%
query = """  SELECT AVG(payloadmass) AS masa_media_transportada FROM SPACEXTBL WHERE serial LIKE 'B1%' """
df  = pd.read_sql(query, con = engine )
df
# Out:
#    masa_media_transportada
# 0              6250.502765

# %% [markdown]
# ### Ejercicio 5
#
# ##### Muestra la fecha donde se realizo el primer aterrizaje exitoso sobre terreno (TRUE RTLS)
#
# *Pista:Utiliza la función min*

# %%
query = """  SELECT date as fecha FROM SPACEXTBL WHERE landingoutcome = 'TRUE RTLS' ORDER BY date LIMIT 1 """
df  = pd.read_sql(query, con = engine )
df
# Out:
#         fecha
# 0  2015-12-22

# %%
query = """  SELECT MIN(date) as fecha FROM SPACEXTBL WHERE landingoutcome = 'TRUE RTLS' ORDER BY date """
df  = pd.read_sql(query, con = engine )
df
# Out:
#         fecha
# 0  2015-12-22

# %% [markdown]
# ### Ejercicio 6
#
# ##### Muestra las series de los cohetes que aterrizaron sobre portaviones (TRUE ASDS) con una masa entre 4000 y 6000

# %%
query = """  SELECT * FROM SPACEXTBL WHERE landingoutcome = 'TRUE ASDS' AND payloadmass BETWEEN 4000 AND 6000 ORDER BY payloadmass DESC """
df  = pd.read_sql(query, con = engine )
df
# Out:
#    FlightNumber        Date BoosterVersion  PayloadMass  \
# 0            55  2018-08-07       Falcon 9       5800.0
# 1            29  2017-03-30       Falcon 9       5300.0
# 2            40  2017-10-11       Falcon 9       5200.0
# 3            70  2019-12-05       Falcon 9       5000.0
# 4            21  2016-05-06       Falcon 9       4696.0
# 5            24  2016-08-14       Falcon 9       4600.0
# 6            59  2018-12-03       Falcon 9       4000.0
#
#                  Payload Orbit    LaunchSite LandingOutcome  Flights  \
# 0               Telkom-4   GTO  CCSFS SLC 40      True ASDS        2
# 1                 SES-10   GTO    KSC LC 39A      True ASDS        2
# 2  SES-11 / Echostar 105   GTO    KSC LC 39A      True ASDS        2
# 3                 CRS-19   ISS  CCSFS SLC 40      True ASDS        1
# 4               JCSAT-2B   GTO  CCSFS SLC 40      True ASDS        1
# 5               JCSAT-16   GTO  CCSFS SLC 40      True ASDS        1
# 6                  SSO-A   SSO   VAFB SLC 4E      True ASDS        3
#
#    GridFins  Reused  Legs                LandingPad  Block  \
# 0         1       1     1  5e9e3032383ecb6bb234e7ca    5.0
# 1         1       1     1  5e9e3032383ecb6bb234e7ca    2.0
# 2         1       1     1  5e9e3032383ecb6bb234e7ca    3.0
# 3         1       0     1  5e9e3032383ecb6bb234e7ca    5.0
# 4         1       0     1  5e9e3032383ecb6bb234e7ca    2.0
# 5         1       0     1  5e9e3032383ecb6bb234e7ca    2.0
# 6         1       1     1  5e9e3033383ecbb9e534e7cc    5.0
#
#                      Customers  Mission_Outcome  ReusedCount Serial  \
# 0                       Telkom                1            3  B1046
# 1                          SES                1            1  B1021
# 2                 SES,Echostar                1            1  B1031
# 3                   NASA (CRS)                1            5  B1059
# 4       SKY Perfect JSAT Group                1            0  B1022
# 5      SKY Perfect JCSAT Group                1            0  B1026
# 6  Spaceflight Industries, Inc                1            3  B1046
#
#     Longitude   Latitude  Class
# 0  -80.577366  28.561857      1
# 1  -80.603956  28.608058      1
# 2  -80.603956  28.608058      1
# 3  -80.577366  28.561857      1
# 4  -80.577366  28.561857      1
# 5  -80.577366  28.561857      1
# 6 -120.610829  34.632093      1

# %% [markdown]
# ### Ejercicio 7
#
# ##### Muestra el numero de lanzamientos que completaron su mision correctamente y aquellos que fallaron

# %%
query = """  SELECT * FROM SPACEXTBL WHERE landingoutcome LIKE '%TRUE%' OR landingoutcome LIKE '%FALSE%' """
df  = pd.read_sql(query, con = engine )
df
# Out:
#     FlightNumber        Date BoosterVersion  PayloadMass  \
# 0              4  2013-09-29       Falcon 9        500.0
# 1              7  2014-04-18       Falcon 9       2296.0
# 2              8  2014-07-14       Falcon 9       1316.0
# 3             11  2014-09-21       Falcon 9       2216.0
# 4             12  2015-01-10       Falcon 9       2395.0
# ..           ...         ...            ...          ...
# 64            86  2020-09-03       Falcon 9      15600.0
# 65            87  2020-10-06       Falcon 9      15600.0
# 66            88  2020-10-18       Falcon 9      15600.0
# 67            89  2020-10-24       Falcon 9      15600.0
# 68            90  2020-11-05       Falcon 9       3681.0
#
#                      Payload Orbit    LaunchSite LandingOutcome  Flights  \
# 0                   CASSIOPE    PO   VAFB SLC 4E    False Ocean        1
# 1                      CRS-3   ISS  CCSFS SLC 40     True Ocean        1
# 2             Orbcomm-OG2-M1   LEO  CCSFS SLC 40     True Ocean        1
# 3                      CRS-4   ISS  CCSFS SLC 40    False Ocean        1
# 4                      CRS-5   ISS  CCSFS SLC 40     False ASDS        1
# ..                       ...   ...           ...            ...      ...
# 64               Starlink-11  VLEO    KSC LC 39A      True ASDS        2
# 65               Starlink-12  VLEO    KSC LC 39A      True ASDS        3
# 66               Starlink-13  VLEO    KSC LC 39A      True ASDS        6
# 67               Starlink-14  VLEO  CCSFS SLC 40      True ASDS        3
# 68  GPS III SV04 (Sacagawea)   MEO  CCSFS SLC 40      True ASDS        1
#
#     GridFins  Reused  Legs                LandingPad  Block  \
# 0          0       0     0                      None    1.0
# 1          0       0     1                      None    1.0
# 2          0       0     1                      None    1.0
# 3          0       0     0                      None    1.0
# 4          1       0     1  5e9e3032383ecb761634e7cb    1.0
# ..       ...     ...   ...                       ...    ...
# 64         1       1     1  5e9e3032383ecb6bb234e7ca    5.0
# 65         1       1     1  5e9e3032383ecb6bb234e7ca    5.0
# 66         1       1     1  5e9e3032383ecb6bb234e7ca    5.0
# 67         1       1     1  5e9e3033383ecbb9e534e7cc    5.0
# 68         1       0     1  5e9e3032383ecb6bb234e7ca    5.0
#
#                     Customers  Mission_Outcome  ReusedCount Serial  \
# 0                         MDA                1            0  B1003
# 1                  NASA (CRS)                1            0  B1006
# 2                     Orbcomm                1            0  B1007
# 3                  NASA (CRS)                1            0  B1010
# 4                  NASA (CRS)                1            0  B1012
# ..                        ...              ...          ...    ...
# 64                     SpaceX                1           12  B1060
# 65                     SpaceX                1           13  B1058
# 66                     SpaceX                1           12  B1051
# 67                     SpaceX                1           12  B1060
# 68  United States Space Force                1            8  B1062
#
#      Longitude   Latitude  Class
# 0  -120.610829  34.632093      0
# 1   -80.577366  28.561857      1
# 2   -80.577366  28.561857      1
# 3   -80.577366  28.561857      0
# 4   -80.577366  28.561857      0
# ..         ...        ...    ...
# 64  -80.603956  28.608058      1
# 65  -80.603956  28.608058      1
# 66  -80.603956  28.608058      1
# 67  -80.577366  28.561857      1
# 68  -80.577366  28.561857      1
#
# [69 rows x 21 columns]

# %% [markdown]
# ### Ejercicio 8
#
# ##### Muestra las series de los cohetes que transportaron la masa máxima

# %%
query = """  SELECT serial, MAX(payloadmass) FROM SPACEXTBL GROUP BY serial ORDER BY MAX(payloadmass) DESC """
df  = pd.read_sql(query, con = engine )
df
# Out:
#    serial  MAX(payloadmass)
# 0   B1048      15600.000000
# 1   B1049      15600.000000
# 2   B1051      15600.000000
# 3   B1056      15600.000000
# 4   B1059      15600.000000
# 5   B1058      15600.000000
# 6   B1060      15600.000000
# 7   B1029       9600.000000
# 8   B1036       9600.000000
# 9   B1041       9600.000000
# 10  B1047       7076.000000
# 11  B1037       6761.000000
# 12  B0003       6123.547647
# 13  B1032       6123.547647
# 14  B1043       6123.547647
# 15  B1046       6123.547647
# 16  B1044       6092.000000
# 17  B1034       6070.000000
# 18  B1030       5600.000000
# 19  B1028       5500.000000
# 20  B1040       5383.850000
# 21  B1021       5300.000000
# 22  B1020       5271.000000
# 23  B1031       5200.000000
# 24  B1016       4707.000000
# 25  B1022       4696.000000
# 26  B1026       4600.000000
# 27  B1008       4535.000000
# 28  B1011       4428.000000
# 29  B1054       4400.000000
# 30  B1042       3700.000000
# 31  B1062       3681.000000
# 32  B1005       3325.000000
# 33  B1004       3170.000000
# 34  B1023       3100.000000
# 35  B1039       2910.000000
# 36  B1035       2708.000000
# 37  B1050       2573.000000
# 38  B1018       2477.000000
# 39  B1045       2410.000000
# 40  B1012       2395.000000
# 41  B1006       2296.000000
# 42  B1025       2257.000000
# 43  B1010       2216.000000
# 44  B1019       2034.000000
# 45  B1015       1898.000000
# 46  B1007       1316.000000
# 47  B0007        677.000000
# 48  B1013        570.000000
# 49  B1017        553.000000
# 50  B0005        525.000000
# 51  B1003        500.000000
# 52  B1038        475.000000

# %% [markdown]
# ### Ejercicio 9
#
# ##### Muestra los el resultados del aterrizaje, la serie del cohete y las plataforma de lanzamiento de aquellos lanzamientos fallidos o no intentados en el año 2015

# %%
query = """  SELECT serial,launchsite, mission_outcome  FROM SPACEXTBL WHERE landingoutcome LIKE '%FALSE%' OR landingoutcome LIKE '%TRUE%' AND date LIKE '2015%' """
df  = pd.read_sql(query, con = engine )
df
# Out:
#    serial    launchsite  mission_outcome
# 0   B1003   VAFB SLC 4E                1
# 1   B1010  CCSFS SLC 40                1
# 2   B1012  CCSFS SLC 40                1
# 3   B1013  CCSFS SLC 40                1
# 4   B1015  CCSFS SLC 40                1
# 5   B1019  CCSFS SLC 40                1
# 6   B1017   VAFB SLC 4E                1
# 7   B1020  CCSFS SLC 40                1
# 8   B1050  CCSFS SLC 40                1
# 9   B1056  CCSFS SLC 40                1
# 10  B1048    KSC LC 39A                1

# %% [markdown]
# ### Ejercicio 10
#
# ##### Muestra los resultados y la frecuencia de estos resultados entre 2010-06-04 y 2017-03-20 ordenados en orden descendiente según la frecuencia

# %%
query = """  SELECT landingoutcome, COUNT(*) as COUNTLAUNCHES  FROM SPACEXTBL 
WHERE date BETWEEN '2010-06-04' AND '2017-03-20'
GROUP BY landingoutcome ORDER BY COUNTLAUNCHES DESC """
df  = pd.read_sql(query, con = engine )
df
# Out:
#   landingoutcome  COUNTLAUNCHES
# 0      None None              9
# 1      True ASDS              5
# 2     False ASDS              4
# 3     True Ocean              3
# 4      True RTLS              3
# 5    False Ocean              2
# 6      None ASDS              2
